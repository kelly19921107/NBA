# %% [markdown]
# ### Import packages

# %%
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.endpoints import scoreboardv2
from nba_api.stats.endpoints import teamgamelog
from nba_api.stats.endpoints import teamdashboardbyyearoveryear
from nba_api.stats.static import teams
from nba_api.stats.static import players

# %% [markdown]
# ### Teams

# %%
allTeams = pd.DataFrame(teams.get_teams())
allTeams.head()
# Out:
#   abbreviation         city             full_name          id   nickname  \
# 0          ATL      Atlanta         Atlanta Hawks  1610612737      Hawks
# 1          BOS       Boston        Boston Celtics  1610612738    Celtics
# 2          CLE    Cleveland   Cleveland Cavaliers  1610612739  Cavaliers
# 3          NOP  New Orleans  New Orleans Pelicans  1610612740   Pelicans
# 4          CHI      Chicago         Chicago Bulls  1610612741      Bulls
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %% [markdown]
# ### Players

# %%
allPlayers = pd.DataFrame(players.get_players())
allPlayers.head()
# Out:
#   first_name            full_name     id     last_name
# 0       Alaa       Alaa Abdelnaby  76001     Abdelnaby
# 1       Zaid      Zaid Abdul-Aziz  76002    Abdul-Aziz
# 2     Kareem  Kareem Abdul-Jabbar  76003  Abdul-Jabbar
# 3    Mahmoud   Mahmoud Abdul-Rauf     51    Abdul-Rauf
# 4      Tariq    Tariq Abdul-Wahad   1505   Abdul-Wahad

# %% [markdown]
# ### Scoreboard

# %%
scoreboardLatest = scoreboardv2.ScoreboardV2()

# %%
scoreboardLatest.game_header.get_data_frame()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2018-10-31T00:00:00              1  0021800104               3
# 1  2018-10-31T00:00:00              2  0021800105               3
# 2  2018-10-31T00:00:00              3  0021800106               3
# 3  2018-10-31T00:00:00              4  0021800107               3
# 4  2018-10-31T00:00:00              5  0021800108               3
# 5  2018-10-31T00:00:00              6  0021800109               3
# 6  2018-10-31T00:00:00              7  0021800110               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20181031/DETBKN    1610612751       1610612765   2018
# 1            Final  20181031/INDNYK    1610612752       1610612754   2018
# 2            Final  20181031/DENCHI    1610612741       1610612743   2018
# 3            Final  20181031/UTAMIN    1610612750       1610612762   2018
# ...

# %%
scoreboardLatest.east_conf_standings_by_day.get_data_frame()
# Out:
#        TEAM_ID LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE          TEAM  G  \
# 0   1610612749        00     22018    10/31/2018       East     Milwaukee  7
# 1   1610612761        00     22018    10/31/2018       East       Toronto  8
# 2   1610612738        00     22018    10/31/2018       East        Boston  7
# 3   1610612754        00     22018    10/31/2018       East       Indiana  8
# 4   1610612765        00     22018    10/31/2018       East       Detroit  7
# 5   1610612766        00     22018    10/31/2018       East     Charlotte  8
# 6   1610612755        00     22018    10/31/2018       East  Philadelphia  8
# 7   1610612748        00     22018    10/31/2018       East         Miami  7
# 8   1610612751        00     22018    10/31/2018       East      Brooklyn  8
# 9   1610612737        00     22018    10/31/2018       East       Atlanta  7
# 10  1610612753        00     22018    10/31/2018       East       Orlando  7
# ...

# %%
scoreboardLatest.west_conf_standings_by_day.get_data_frame()
# Out:
#        TEAM_ID LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE           TEAM  G  \
# 0   1610612744        00     22018    10/31/2018       West   Golden State  9
# 1   1610612743        00     22018    10/31/2018       West         Denver  7
# 2   1610612757        00     22018    10/31/2018       West       Portland  7
# 3   1610612759        00     22018    10/31/2018       West    San Antonio  7
# 4   1610612763        00     22018    10/31/2018       West        Memphis  6
# 5   1610612758        00     22018    10/31/2018       West     Sacramento  8
# 6   1610612746        00     22018    10/31/2018       West    LA Clippers  7
# 7   1610612740        00     22018    10/31/2018       West    New Orleans  7
# 8   1610612762        00     22018    10/31/2018       West           Utah  7
# 9   1610612750        00     22018    10/31/2018       West      Minnesota  8
# 10  1610612747        00     22018    10/31/2018       West    L.A. Lakers  8
# ...

# %% [markdown]
# ### Team Game Log

# %%
MILTeamGameLog = teamgamelog.TeamGameLog(team_id=1610612749)

# %%
MIL = MILTeamGameLog.team_game_log.get_data_frame()
MIL
# Out:
#       Team_ID     Game_ID     GAME_DATE      MATCHUP WL  W  L  W_PCT  MIN  \
# 0  1610612749  0021800092  OCT 29, 2018  MIL vs. TOR  W  7  0    1.0  240
# 1  1610612749  0021800081  OCT 27, 2018  MIL vs. ORL  W  6  0    1.0  240
# 2  1610612749  0021800071  OCT 26, 2018    MIL @ MIN  W  5  0    1.0  240
# 3  1610612749  0021800059  OCT 24, 2018  MIL vs. PHI  W  4  0    1.0  240
# 4  1610612749  0021800042  OCT 22, 2018  MIL vs. NYK  W  3  0    1.0  240
# 5  1610612749  0021800023  OCT 19, 2018  MIL vs. IND  W  2  0    1.0  240
# 6  1610612749  0021800003  OCT 17, 2018    MIL @ CHA  W  1  0    1.0  240
#
#    FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   45 ...    0.789     8    49   57   28    5    4   17  21  124
# 1   41 ...    0.913     6    51   57   24    6    7   21  19  113
# 2   49 ...    0.727     7    55   62   32    4    8   17  23  125
# 3   41 ...    0.933     9    42   51   24    7   10   11  27  123
# ...

# %% [markdown]
# ### Team Dashboard By Year Over Year

# %%
GSWTeamDash = teamdashboardbyyearoveryear.TeamDashboardByYearOverYear(team_id=1610612744)

# %%
GSWTeamDashOverall = GSWTeamDash.overall_team_dashboard.get_data_frame()
GSWTeamDashOverall
# Out:
#   GROUP_SET GROUP_VALUE  GP   W   L  W_PCT     MIN   FGM   FGA  FG_PCT  \
# 0   Overall     2017-18  82  58  24  0.707  3946.0  3509  6979   0.503
#
#      ...     TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  \
# 0    ...            1         1         1          1        1         1
#
#    PTS_RANK  PLUS_MINUS_RANK  CFID  CFPARAMS
# 0         1                1   211   2017-18
#
# [1 rows x 56 columns]

# %%
GSWTeamDash.by_year_team_dashboard.get_data_frame()
# Out:
#    GROUP_SET GROUP_VALUE  GP   W   L  W_PCT          MIN   FGM   FGA  FG_PCT  \
# 0    By Year     2018-19   9   8   1  0.889   432.000000   420   802   0.524
# 1    By Year     2017-18  82  58  24  0.707  3946.000000  3509  6979   0.503
# 2    By Year     2016-17  82  67  15  0.817  3956.000000  3532  7140   0.495
# 3    By Year     2015-16  82  73   9  0.890  3976.000000  3489  7159   0.487
# 4    By Year     2014-15  82  67  15  0.817  3946.000000  3410  7137   0.478
# 5    By Year     2013-14  82  51  31  0.622  3966.000000  3236  7005   0.462
# 6    By Year     2012-13  82  47  35  0.573  3961.000000  3130  6840   0.458
# 7    By Year     2011-12  66  23  43  0.348  3183.000000  2489  5443   0.457
# 8    By Year     2010-11  82  36  46  0.439  3966.000000  3251  7047   0.461
# 9    By Year     2009-10  82  26  56  0.317  3946.000000  3329  7094   0.469
# 10   By Year     2008-09  82  29  53  0.354  3975.998333  3231  7055   0.458
# ...
